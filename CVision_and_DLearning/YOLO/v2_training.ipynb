# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/SourceCode/OJT/Yolo_training')

# %%
ls
# Out:
# bus.jpg                                                 dataset.zip    yolo_training.ipynb
# calibration_image_sample_data_20x128x128x3_float32.npy  data_test/     yolov8m.pt
# convert_model/                                          model_45_API/
# data/                                                   runs/

# %% [markdown]
# # Setup thư viện

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !yolo --version
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING ⚠️ argument '--version' does not require leading dashes '--', updating to 'version'.
# 8.3.97

# %% [markdown]
# # Predict với pretrain weights

# %%
from ultralytics import YOLO

# Đường dẫn lưu model
save_path = "/content/drive/MyDrive/SourceCode/OJT/Yolo_training/yolov8m.pt"

# Tải model nếu chưa có
model = YOLO("yolov8m.pt")
print("Tải model thành công:", model)

# Chạy inference với hình ảnh online
model.predict(source="https://ultralytics.com/images/bus.jpg", save=True)
# Out:
# Tải model thành công: YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
# Predict detection bằng CLI
# !yolo task=detect mode=predict model=yolov8m.pt source="https://nextcity.org/images/made/219951734_2838e034bb_o_840_630_80.jpg"
# Out:
# Ultralytics 8.3.97 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8m summary (fused): 92 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
#
# Found https://nextcity.org/images/made/219951734_2838e034bb_o_840_630_80.jpg locally at 219951734_2838e034bb_o_840_630_80.jpg
# image 1/1 /content/drive/MyDrive/SourceCode/OJT/Yolo_training/219951734_2838e034bb_o_840_630_80.jpg: 480x640 15 persons, 4 bicycles, 4 motorcycles, 58.7ms
# Speed: 2.9ms preprocess, 58.7ms inference, 160.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load model YOLOv8m-seg
model = YOLO("yolov8m.pt")

# Predict trên ảnh từ URL (tải ảnh xuống)
image_url = "https://nextcity.org/images/made/219951734_2838e034bb_o_840_630_80.jpg"
results = model.predict(source=image_url, save=True)
# Out:
# Found https://nextcity.org/images/made/219951734_2838e034bb_o_840_630_80.jpg locally at 219951734_2838e034bb_o_840_630_80.jpg
# image 1/1 /content/drive/MyDrive/SourceCode/OJT/Yolo_training/219951734_2838e034bb_o_840_630_80.jpg: 480x640 15 persons, 4 bicycles, 4 motorcycles, 28.8ms
# Speed: 2.4ms preprocess, 28.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict3

# %%
ls
# Out:
# drive/  sample_data/

# %% [markdown]
# ## Training YOLO v8m model with Custom data

# %%
# %mkdir -p /content/drive/MyDrive/SourceCode/OJT/Yolo_training/data

# %%
import os

# Đường dẫn lưu dataset
save_dir = "/content/drive/MyDrive/SourceCode/OJT/Yolo_training/data"

# Link tải dataset từ Roboflow
dataset_url = "https://app.roboflow.com/ds/C9Yd3UmR0F?key=3lwjSdzdA8"

# Lệnh tải file
os.system(f"wget -O {save_dir}/dataset.zip '{dataset_url}'")
os.system(f"unzip {save_dir}/dataset.zip -d {save_dir}")
# Out:
# 0

# %%
import torch

# Kiểm tra và chọn thiết bị (GPU nếu có, nếu không dùng CPU)
device = "0" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Chạy YOLOv8 với thiết bị đã chọn
# !yolo task=detect mode=train model=yolov8m.pt data=/content/drive/MyDrive/SourceCode/OJT/Yolo_training/data/data.yaml epochs=70 imgsz=640 device={device} degrees=45
# Out:
# Using device: 0
# Ultralytics 8.3.97 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ## 📊 Summary
#
# + ⏱️ **Time**: 0.490 hours
# + 🎯 **P (Precision - Độ chính xác)**: 0.881
# + 📊 **R (Recall - Độ nhạy)**: 0.815
# + 📈 **mAP50 (Mean Average Precision @0.5)**: 0.913
# + 📉 **mAP50-95 (Mean Average Precision @0.5:0.95)**: 0.447
#
# ## ⚡ Inference Speed (Tốc độ suy luận)
#
# + 🧹 **Preprocess**: 0.3ms
# + 🧠 **Inference**: 11.0ms
# + 🛠️ **Postprocess**: 4.3ms

# %%
import torch
from ultralytics import YOLO

# Kiểm tra và chọn thiết bị (GPU nếu có, nếu không thì dùng CPU)
device = 0 if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Load mô hình YOLOv8m
model = YOLO("yolov8m.pt")

# Huấn luyện mô hình với tập dữ liệu của bạn
model.train(
    data="/content/drive/MyDrive/SourceCode/OJT/Yolo_training/data/data.yaml",
    epochs=70,
    imgsz=640,
    device=device,
    degrees=45
)
# Out:
# Using device: 0
# Ultralytics 8.3.97 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # 🔍 Kết quả huấn luyện YOLOv8
#
# | Thông số               | Giá trị       |
# |------------------------|---------------|
# | ⏱️ Thời gian huấn luyện   | 0.469 giờ      |
# | 🎯 Precision (P)           | 0.881         |
# | 📊 Recall (R)              | 0.815         |
# | 📈 mAP@0.5                 | 0.913         |
# | 📉 mAP@0.5:0.95            | 0.447         |
#
# # ⚡ Tốc độ suy luận (Inference Speed)
#
# | Giai đoạn       | Thời gian (ms) |
# |------------------|----------------|
# | Preprocess       | 0.2 ms         |
# | Inference        | 10.9 ms        |
# | Postprocess      | 3.9 ms         |

# %% [markdown]
# # Export to onnx

# %%
#install for export
# !pip install ultralytics onnx onnx-simplifier openvino-dev coremltools --quiet onnxruntime-gpu --quiet

# %%
# export model in api
# !python /content/drive/MyDrive/SourceCode/OJT/Yolo_training/export_yolov8.py \
  --weights /content/drive/MyDrive/SourceCode/OJT/Yolo_training/runs/detect/train2/weights/best.pt \
  --include onnx torchscript openvino tflite \
  --device gpu \
  --simplify
# Out:
# 🚀 Exporting to ONNX...
# Ultralytics 8.3.97 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/SourceCode/OJT/Yolo_training/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (49.6 MB)
# requirements: Ultralytics requirements ['onnxslim', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.1/144.1 kB 34.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.8/280.8 MB 173.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 171.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 311.2 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 15.1s, installed 2 packages: ['onnxslim', 'onnxruntime-gpu']
# ...

# %% [markdown]
# ## ✅ ONNX: best.onnx
# ## ✅ TorchScript: best.torchscript
# ## ✅ OpenVINO: best_openvino_model/
# ## ✅ TFLite: best_float32.tflite, best_full_integer_quant.tflite hoặc tương tự
# ## => File .tflite nằm cùng thư mục hoặc /tmp/..., bạn kiểm tra sau export

# %% [markdown]
# # Test model best.pt

# %%
#import for pt
# !pip install numpy==1.23.5 --force-reinstall --no-cache-dir
# !pip install sympy==1.11.1 --force-reinstall --no-cache-dir
# !pip install --upgrade --force-reinstall ultralytics

import os
os.kill(os.getpid(), 9)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 235.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.89 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# pymc 5.21.1 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.23.5 which is incompatible.
# xarray 2025.1.2 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# blosc2 3.2.0 requires numpy>=1.26, but you have numpy 1.23.5 which is incompatible.
# albucore 0.0.23 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
from ultralytics import YOLO
import torch
import cv2
import matplotlib.pyplot as plt

# ⚙️ Cấu hình
image_path = '/content/drive/MyDrive/SourceCode/OJT/Yolo_training/data_test/face_test.jpg'
model_path = '/content/drive/MyDrive/SourceCode/OJT/Yolo_training/model_45_API/PyTorch_model/best.pt'

# 🧠 Kiểm tra thiết bị
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print(f"Đang chạy trên: {device}")

# 🧠 Load model
model = YOLO(model_path).to(device)

# 📷 Load ảnh
img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# ▶️ Inference với confidence thấp hơn
results = model(img_rgb, device=device, conf=0.1)[0]

# 📦 Vẽ bounding box lên ảnh
for box in results.boxes:
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    conf = float(box.conf[0])
    cls_id = int(box.cls[0])
    label = f"{model.names[cls_id]}: {conf:.2f}"

    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX,
                0.5, (0, 255, 0), 2)

# 🖼️ Hiển thị kết quả
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Kết quả từ YOLOv8 .pt (conf=0.1)")
plt.axis(False)
plt.show()
# Out:
# Đang chạy trên: cuda:0
#
# 0: 416x640 3 Faces, 143.0ms
# Speed: 8.0ms preprocess, 143.0ms inference, 319.5ms postprocess per image at shape (1, 3, 416, 640)

# %% [markdown]
# # TEST MODEL ONNX

# %%
# !pip install onnxruntime-gpu --quiet

# %%
import onnxruntime
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# ⚙️ Cấu hình
image_path = '/content/drive/MyDrive/SourceCode/OJT/Yolo_training/data_test/test4.jpg'
onnx_model_path = '/content/drive/MyDrive/SourceCode/OJT/Yolo_training/model_45_API/Onnx/best.onnx'
CONF_THRESHOLD = 0.3
# Each bounding box predicted by the model comes with a confidence (conf) value between 0 and 1.
# → This helps you keep only the boxes with confidence greater than or equal to the threshold.
IOU_THRESHOLD = 0.5
CLASSES = ['face']  # 🛠️ Sửa theo nhãn của bạn
COLORS = [(0, 255, 0)]

# 📤 Hàm chuyển bbox
def xywh2xyxy(x):
    y = np.copy(x)
    y[0] = x[0] - x[2] / 2
    y[1] = x[1] - x[3] / 2
    y[2] = x[0] + x[2] / 2
    y[3] = x[1] + x[3] / 2
    return y

# 🧠 Load model ONNX
session = onnxruntime.InferenceSession(
    onnx_model_path,
    providers=['CUDAExecutionProvider', 'CPUExecutionProvider']
)

# 🖼️ Load & chuẩn hóa ảnh
img = cv2.imread(image_path)
orig_img = img.copy()
img_resized = cv2.resize(img, (640, 640))
img_input = img_resized[..., ::-1].transpose(2, 0, 1)  # BGR → RGB → CHW
img_input = np.expand_dims(img_input, axis=0).astype(np.float32) / 255.0

# ▶️ Inference
input_name = session.get_inputs()[0].name
outputs = session.run(None, {input_name: img_input})
pred = np.squeeze(outputs[0]).T  # (8400, 5)

# 📦 Post-processing
boxes = []
scores = []
class_ids = []

for i in range(pred.shape[0]):
    x, y, w, h, conf = pred[i][:5]
    if conf > CONF_THRESHOLD:
        box = xywh2xyxy([
            x * orig_img.shape[1],
            y * orig_img.shape[0],
            w * orig_img.shape[1],
            h * orig_img.shape[0]
        ])
        boxes.append([int(b) for b in box])
        scores.append(float(conf))
        class_ids.append(0)  # Chỉ có 1 class

# 🧹 NMS
indices = cv2.dnn.NMSBoxes(boxes, scores, CONF_THRESHOLD, IOU_THRESHOLD)

# 🎨 Vẽ kết quả
if len(indices) > 0:
    for i in indices.flatten():
        x1, y1, x2, y2 = boxes[i]
        conf = scores[i]
        cls_id = class_ids[i]
        label = f"{CLASSES[cls_id]}: {conf:.2f}"
        color = COLORS[cls_id % len(COLORS)]

        cv2.rectangle(orig_img, (x1, y1), (x2, y2), color, 2)
        cv2.putText(orig_img, label, (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

# 📷 Hiển thị kết quả
print("Output shape:", outputs[0].shape)
plt.imshow(cv2.cvtColor(orig_img, cv2.COLOR_BGR2RGB))
plt.title("Kết quả từ ONNX")
plt.axis(False)
plt.show()
# Out:
# Output shape: (1, 5, 8400)

# %% [markdown]
# # TEST Model TFLite

# %%
# Gỡ  & cài đúng phiên bản
# !pip uninstall -y numpy tensorflow
# !pip install numpy==1.26.4 --no-cache-dir --force-reinstall
# !pip install tensorflow==2.15.0 --no-cache-dir --force-reinstall
# Out:
# Found existing installation: numpy 1.24.3
# Uninstalling numpy-1.24.3:
#   Successfully uninstalled numpy-1.24.3
# Found existing installation: tensorflow 2.13.0
# Uninstalling tensorflow-2.13.0:
#   Successfully uninstalled tensorflow-2.13.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 245.9 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# nibabel 5.3.2 requires typing-extensions>=4.6; python_version < "3.13", but you have typing-extensions 4.5.0 which is incompatible.
# nx-cugraph-cu12 25.2.0 requires networkx>=3.2, but you have networkx 3.1 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 13.2 MB/s eta 0:00:00
# ...

# %%
# !pip install tensorflow==2.13.0 --no-cache-dir --force-reinstall
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.2/524.2 MB 224.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.3/277.3 kB 338.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 284.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 276.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 191.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 277.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 272.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 263.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 316.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 367.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 184.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 313.5 MB/s eta 0:00:00
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image

# 🔧 Cấu hình
image_path = '/content/drive/MyDrive/SourceCode/OJT/Yolo_training/data_test/test1.jpg'
tflite_model_path = '/content/drive/MyDrive/SourceCode/OJT/Yolo_training/model_45_API/Model_TFLite/best_float32.tflite'
CONF_THRESHOLD = 0.4
IOU_THRESHOLD = 0.5
CLASSES = ['face']
COLORS = [(255, 0, 0)]

# 📤 Hàm chuyển bbox
def xywh2xyxy(x):
    y = np.copy(x)
    y[0] = x[0] - x[2] / 2
    y[1] = x[1] - x[3] / 2
    y[2] = x[0] + x[2] / 2
    y[3] = x[1] + x[3] / 2
    return y

# 🧠 Load model TFLite
interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# 📷 Load ảnh
img = cv2.imread(image_path)
orig_img = img.copy()
img_resized = cv2.resize(img, (640, 640))
img_input = img_resized[..., ::-1].astype(np.float32) / 255.0  # BGR → RGB + normalize
img_input = np.expand_dims(img_input, axis=0)

# ▶️ Inference
interpreter.set_tensor(input_details[0]['index'], img_input)
interpreter.invoke()
output_data = interpreter.get_tensor(output_details[0]['index'])  # (1, 8400, 5)
pred = np.squeeze(output_data).T  # (5, 8400) → (8400, 5)

# 📦 Post-processing
boxes, scores, class_ids = [], [], []
for i in range(pred.shape[0]):
    x, y, w, h, conf = pred[i][:5]
    if conf > CONF_THRESHOLD:
        box = xywh2xyxy([
            x * orig_img.shape[1],
            y * orig_img.shape[0],
            w * orig_img.shape[1],
            h * orig_img.shape[0]
        ])
        boxes.append([int(b) for b in box])
        scores.append(float(conf))
        class_ids.append(0)

indices = cv2.dnn.NMSBoxes(boxes, scores, CONF_THRESHOLD, IOU_THRESHOLD)

# 🎨 Vẽ kết quả
for i in indices.flatten():
    x1, y1, x2, y2 = boxes[i]
    conf = scores[i]
    cls_id = class_ids[i]
    label = f"{CLASSES[cls_id]}: {conf:.2f}"
    color = COLORS[cls_id % len(COLORS)]
    cv2.rectangle(orig_img, (x1, y1), (x2, y2), color, 2)
    cv2.putText(orig_img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

# 🖼️ Hiển thị
print("TFLite output shape:", output_data.shape)
plt.imshow(cv2.cvtColor(orig_img, cv2.COLOR_BGR2RGB))
plt.title("Kết quả từ TFLite")
plt.axis(False)
plt.show()
# Out:
# TFLite output shape: (1, 5, 8400)

# %%
import tensorflow as tf
import numpy as np

print("✅ TensorFlow:", tf.__version__)
print("✅ NumPy:", np.__version__)
# Out:
# ✅ TensorFlow: 2.15.0
# ✅ NumPy: 1.26.4

# %% [markdown]
# # TEST Model OpenVINO

# %%
from openvino.runtime import Core
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# ---------- Hàm Non-Maximum Suppression ----------
def non_max_suppression(boxes, scores, iou_threshold=0.5):
    boxes = np.array(boxes)
    scores = np.array(scores)
    indices = cv2.dnn.NMSBoxes(boxes.tolist(), scores.tolist(), score_threshold=0.25, nms_threshold=iou_threshold)
    return indices.flatten() if len(indices) > 0 else []

# ---------- Load model OpenVINO ----------
core = Core()
model_path = "/content/drive/MyDrive/SourceCode/OJT/Yolo_training/model_45_API/Model_Openvino/best.xml"
compiled_model = core.compile_model(model_path, "CPU")

# ---------- Load ảnh ----------
image_path = '/content/drive/MyDrive/SourceCode/OJT/Yolo_training/data_test/test2.jpg'
original_img = cv2.imread(image_path)
img_resized = cv2.resize(original_img, (640, 640))
img_input = img_resized[..., ::-1].transpose(2, 0, 1)
img_input = np.expand_dims(img_input, axis=0).astype(np.float32) / 255.0

# ---------- Inference ----------
input_layer = compiled_model.input(0)
output_layer = compiled_model.output(0)
result = compiled_model([img_input])[output_layer]

# ---------- Postprocess ----------
conf_threshold = 0.3
boxes = []
scores = []

for det in result[0].T:  # (5, 8400)
    if det[4] > conf_threshold:
        x_center, y_center, w, h = det[0:4]
        x1 = int((x_center - w / 2) * original_img.shape[1] / 640)
        y1 = int((y_center - h / 2) * original_img.shape[0] / 640)
        x2 = int((x_center + w / 2) * original_img.shape[1] / 640)
        y2 = int((y_center + h / 2) * original_img.shape[0] / 640)
        boxes.append([x1, y1, x2 - x1, y2 - y1])  # Format cho NMS: [x, y, w, h]
        scores.append(float(det[4]))

# ---------- Apply NMS ----------
indices = non_max_suppression(boxes, scores, iou_threshold=0.5)

# ---------- Vẽ kết quả ----------
for i in indices:
    x, y, w, h = boxes[i]
    conf = scores[i]
    label = f'Face {conf:.2f}'

    # Vẽ khung với độ dày lớn hơn (thickness = 6)
    cv2.rectangle(original_img, (x, y), (x + w, y + h), (0, 255, 0), 6)

    # Hiển thị nhãn với font lớn hơn và nét chữ dày (thickness = 3)
    cv2.putText(original_img, label, (x, y - 15),
                cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 0), 3)

# ---------- Hiển thị ----------
print("Output shape:", result.shape)
plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
plt.title("Kết quả từ OpenVINO")
plt.axis(False)
plt.show()
# Out:
# Output shape: (1, 5, 8400)

# %% [markdown]
# # Test model torchscript

# %%
import torch
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# -------- Load TorchScript model ----------
model_path = '/content/drive/MyDrive/SourceCode/OJT/Yolo_training/model_45_API/PyTorch_model/best.torchscript'
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = torch.jit.load(model_path, map_location=device).eval().to(device)

# -------- Load và xử lý ảnh ----------
image_path = '/content/drive/MyDrive/SourceCode/OJT/Yolo_training/data_test/test3.jpg'
original_img = cv2.imread(image_path)
img_resized = cv2.resize(original_img, (640, 640))
img = img_resized[..., ::-1].transpose(2, 0, 1)  # BGR -> RGB -> CHW
img = np.expand_dims(img, 0).astype(np.float32) / 255.0
img_tensor = torch.from_numpy(img).to(device)

# -------- Inference ----------
with torch.no_grad():
    preds = model(img_tensor)

# -------- Postprocess ----------
conf_threshold = 0.3
preds_np = preds.cpu().numpy().T  # (8400, 5 + num_classes)
num_classes = preds_np.shape[1] - 4  # 4 bbox + scores

boxes = []
scores = []
class_ids = []

h_orig, w_orig = original_img.shape[:2]

for d in preds_np:
    class_scores = d[4:]
    class_id = np.argmax(class_scores)
    score = class_scores[class_id]

    if score > conf_threshold:
        x_center, y_center, w, h = d[:4]
        x1 = int((x_center - w / 2) * w_orig / 640)
        y1 = int((y_center - h / 2) * h_orig / 640)
        x2 = int((x_center + w / 2) * w_orig / 640)
        y2 = int((y_center + h / 2) * h_orig / 640)
        boxes.append([x1, y1, x2 - x1, y2 - y1])
        scores.append(float(score))
        class_ids.append(int(class_id))

# -------- Apply NMS --------
indices = cv2.dnn.NMSBoxes(boxes, scores, conf_threshold, 0.5)

# -------- Vẽ bounding boxes --------
for i in indices:
    i = i[0] if isinstance(i, (list, np.ndarray)) else i
    x, y, w, h = boxes[i]
    score = scores[i]
    class_id = class_ids[i]
    label = f"Face {class_id} | {score:.2f}"

    cv2.rectangle(original_img, (x, y), (x + w, y + h), (0, 255, 0), 6)  # Nét đậm hơn
    cv2.putText(original_img, label, (x, y - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 0), 3)

# -------- Hiển thị ----------
plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
plt.title("Kết quả từ TorchScript")
plt.axis(False)
plt.show()
# Out:
# <ipython-input-5-0f1db0542ad3>:42: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x1 = int((x_center - w / 2) * w_orig / 640)
# <ipython-input-5-0f1db0542ad3>:43: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y1 = int((y_center - h / 2) * h_orig / 640)
# <ipython-input-5-0f1db0542ad3>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x2 = int((x_center + w / 2) * w_orig / 640)
# ...
